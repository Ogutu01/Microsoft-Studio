# %% [markdown]
# # Microsoft's Cinematic Endeavour: A Data-Backed Approach

# %% [markdown]
# #### Authors: Joy Achieng Ogutu

# %% [markdown]
# ## Project Overview
# This endeavor deals with the commercial issue Microsoft is experiencing as it establishes a new film production company. Microsoft wants to use data-driven insights to guide its creative decision-making in the film industry. We've carried out a thorough investigation using a number of Python data manipulation and analytical techniques. Data cleaning, exploratory data analysis (EDA), statistical analysis, and data visualization approaches were all included in our methodology. We used Python modules like Pandas, NumPy, Matplotlib, and Seaborn to derive useful insights from a large dataset that we combined from sources such as Box Office Mojo, The Movie Database and The Numbers.The results of our analysis unveil the key determinants of movie success, illuminate market competition dynamics, and assess the financial impact of production budgets. Our recommendations encompass language selection, competitive positioning, and prudent budget allocation. By harnessing these insights, Microsoft can navigate the intricate movie industry landscape and establish a successful movie studio that aligns with audience preferences and maximizes profitability.

# %% [markdown]
# ## Business Problem.
# Microsoft seeks to establish itself as a prominent player in the movie production industry, but its limited expertise poses significant challenges. The primary pain points revolve around making informed decisions regarding movie production, including movie language selection, budget allocation and competitive positioning. Microsoft requires insights to address these concerns effectively and establish a successful movie studio.
#
# Questions to consider:
#
# 1. What are the key factors driving the success of movies in terms of box office performance?
# We will explore the determinants of movie success, including language, popularity, and audience sentiment, to inform language    selection and narrative development.
#
# 2. Who are the major players in the movie industry, and what is their market share?
# In order to find possible partners, collaborators, or business opportunities for Microsoft's movie studio, a competitive analysis of the market is essential.
#
# 3. How does the allocation of production budgets impact the financial performance of movies?
# We will evaluate the connection between spending decisions and financial results, assisting Microsoft in making wise spending decisions and maximizing profitability.
#
# The fact that these data queries directly address Microsoft's primary operational issue is why they were chosen. They offer perceptions into the crucial facets of filmmaking, ensuring well-informed choices and a successful studio launch.
# Understanding the factors that contribute to a film's success helps Microsoft's films reflect consumer preferences and maximize box office revenue through language choice and narrative development.
#
# In order to get a presence in the film industry, competitive positioning and partner identification are made easier by profiling the market competition.
#
# Microsoft is able to properly deploy resources by analyzing the influence of production budgets on financial performance, establishing a balance between innovation and thriftiness, and achieving long-term success.

# %% [markdown]
# ## Data Understanding.
# We tapped into insights from many databases that offer a comprehensive view of the business in our investigation of the environment of film production. These datasets include:
# 1.	Box Office Mojo:
# This dataset contains essential details about movie performance, including the Movie Title, Studio responsible for production, Domestic gross earnings, Foreign gross earnings, and the Release year.
# 2.	The Movie Database:
# The second dataset from TMDB offers insights into movie attributes such as Genre ID, Original Language, Original Title, Popularity, Release Date, Title, Vote Average and Vote Counts.
# 3.	The Numbers:
# The third dataset, sourced from The Numbers, focuses on the financial aspects of movies, encompassing Release Dates, Movie Titles, Production Budget, Domestic gross earnings, and Worldwide gross earnings.
#
# Together, these datasets offer a complete picture of the movie business, including measurements for movie performance, financial information and movie qualities. These datasets are directly addressed by the data analysis questions, which seek to glean valuable insights for Microsoft's filmmaking endeavor.These data links enabled us to create a substantial and well-organized dataset that forms the basis of our analysis. The dataset's important columns are listed below:
# 1.	Title: The title of the film serves as an identification number.
# 2.	Studio: The entity responsible for production of the movie.
# 3.	Genre ID: The genre ID representing the genre of the movie.
# 4.	Original Language: The language in which the film was first made.
# 5.	Popularity: A measure of a film's popularity.
# 6.	Vote Average: The overall score that viewers gave the film.
# 7.	Vote Count: The total number of votes and reviews received by the movie.
# 8.	Production Budget: The sum of money set aside for the movie’s production.
# 9.	Domestic Gross: Total revenue made from the movie's domestic release in the nation where it was produced.
# 10.	Worldwide Gross: The sum of the movie's worldwide box office receipts.

# %% [markdown]
# ### Loading standard packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Importing and exploring the data
# Loading the data from a file into a DataFrame. To investigate the DataFrame, we use a method called .head(n) or .tail(n), which will respectively return first and last n items in the DataFrame.

# %%
bom_df1 = pd.read_csv("bom.movie_gross.csv")
bom_df1.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# Creating a function called that will return the dataframe's type, shape, info as well as its description.

# %%
def df_info (df):
    print("df type: ", type(df), "\n")
    print("df shape: ", df.shape, "\n")
    print("df info: ", df.info(), "\n")
    print("df description: ", df.describe(), "\n")

# %%
df_info(bom_df1)
# Out:
# df type:  <class 'pandas.core.frame.DataFrame'>
#
# df shape:  (3387, 5)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# df info:  None
#
# df description:         domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
tmdb_df2 = pd.read_csv("tmdb.movies.csv", index_col = 0)
tmdb_df2.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# ...

# %%
df_info(tmdb_df2)
# Out:
# df type:  <class 'pandas.core.frame.DataFrame'>
#
# df shape:  (26517, 9)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  object
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.0+ MB
# df info:  None
#
# df description:                    id    popularity  vote_average    vote_count
# count   26517.000000  26517.000000  26517.000000  26517.000000
# ...

# %%
tnm_budgets_df3 = pd.read_csv("tn.movie_budgets.csv")
tnm_budgets_df3
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
df_info(tnm_budgets_df3)
# Out:
# df type:  <class 'pandas.core.frame.DataFrame'>
#
# df shape:  (5782, 6)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# df info:  None
#
# df description:                  id
# count  5782.000000
# mean     50.372363
# std      28.821076
# min       1.000000
# 25%      25.000000
# 50%      50.000000
# 75%      75.000000
# max     100.000000

# %% [markdown]
# Next we will merge the three DataFrames resulting in one larger DataFrame containing the contents in the order they were merged in.

# %%
merged_df1_df2 = pd.merge(bom_df1, tmdb_df2, left_on = "title",right_on = "title", how = "inner")
merged_df1_df2.head()
# Out:
#                         title studio  domestic_gross foreign_gross  year  \
# 0                 Toy Story 3     BV     415000000.0     652000000  2010
# 1                   Inception     WB     292600000.0     535700000  2010
# 2         Shrek Forever After   P/DW     238700000.0     513900000  2010
# 3  The Twilight Saga: Eclipse   Sum.     300500000.0     398000000  2010
# 4                  Iron Man 2   Par.     312400000.0     311500000  2010
#
#                  genre_ids     id original_language  \
# 0          [16, 10751, 35]  10193                en
# 1            [28, 878, 12]  27205                en
# 2  [35, 12, 14, 16, 10751]  10192                en
# 3      [12, 14, 18, 10749]  24021                en
# 4            [12, 28, 878]  10138                en
#
#                original_title  popularity release_date  vote_average  \
# 0                 Toy Story 3      24.445   2010-06-17           7.7
# 1                   Inception      27.920   2010-07-16           8.3
# ...

# %%
merged_df = pd.merge(merged_df1_df2, tnm_budgets_df3, left_on = "title", right_on = "movie", how = "inner")
merged_df.head()
# Out:
#                         title studio  domestic_gross_x foreign_gross  year  \
# 0                 Toy Story 3     BV       415000000.0     652000000  2010
# 1                   Inception     WB       292600000.0     535700000  2010
# 2         Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3  The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                  Iron Man 2   Par.       312400000.0     311500000  2010
#
#                  genre_ids   id_x original_language  \
# 0          [16, 10751, 35]  10193                en
# 1            [28, 878, 12]  27205                en
# 2  [35, 12, 14, 16, 10751]  10192                en
# 3      [12, 14, 18, 10749]  24021                en
# 4            [12, 28, 878]  10138                en
#
#                original_title  popularity release_date_x  vote_average  \
# 0                 Toy Story 3      24.445     2010-06-17           7.7
# ...

# %%
df_info(merged_df)
# Out:
# df type:  <class 'pandas.core.frame.DataFrame'>
#
# df shape:  (1395, 19)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1395 entries, 0 to 1394
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1395 non-null   object
#  1   studio             1394 non-null   object
#  2   domestic_gross_x   1393 non-null   float64
#  3   foreign_gross      1200 non-null   object
#  4   year               1395 non-null   int64
#  5   genre_ids          1395 non-null   object
#  6   id_x               1395 non-null   int64
#  7   original_language  1395 non-null   object
#  8   original_title     1395 non-null   object
#  9   popularity         1395 non-null   float64
#  10  release_date_x     1395 non-null   object
#  11  vote_average       1395 non-null   float64
#  12  vote_count         1395 non-null   int64
#  13  id_y               1395 non-null   int64
# ...

# %% [markdown]
# The resulting DataFrame contains 1395 rows and 19 columns.

# %% [markdown]
# ## Data Preparation
# Data preparation is a crucial stage in this project for a number of reasons, including:
#
# * Data Quality Assurance: Ensuring data quality is crucial. Errors, missing values, and inconsistent data are all possible. We can find and fix these problems by carefully gathering the data, ensuring the dependability of our analysis.
#
# * Data Integration: We are utilizing a number of datasets from various sources. By addressing differences in variable names, units, and formats, data preparation enables us to harmonize these datasets, allowing for meaningful cross-referencing and analysis.
#
# * Feature engineering: New features might be developed or current ones modified in order to improve analysis.
#
# * Handling Missing Data: Analysis results can be greatly impacted by missing data. In order to achieve a robust analysis, handling missing values must be decided, whether through imputation, deletion, or other suitable approaches.
#
# * Outlier detection: For statistical validity, outliers must be found and dealt with. We can use methods like visual inspection or statistical testing to find outliers and handle them correctly with the help of data preparation.

# %% [markdown]
# We will drop the columns that we do not require for the analysis.

# %%
# Dropping unnecessary columns from the DataFrame

# Creating a list of columns to drop
cols_to_remove = ["domestic_gross_x","foreign_gross", "year","id_x","original_title", "release_date_x", "id_y", "release_date_y", "movie"]
cols = [col for col in merged_df if col not in cols_to_remove]
merged_df = merged_df[cols]

merged_df.head() # This results in a shape of shape (1395, 10)
# Out:
#                         title studio                genre_ids  \
# 0                 Toy Story 3     BV          [16, 10751, 35]
# 1                   Inception     WB            [28, 878, 12]
# 2         Shrek Forever After   P/DW  [35, 12, 14, 16, 10751]
# 3  The Twilight Saga: Eclipse   Sum.      [12, 14, 18, 10749]
# 4                  Iron Man 2   Par.            [12, 28, 878]
#
#   original_language  popularity  vote_average  vote_count production_budget  \
# 0                en      24.445           7.7        8340      $200,000,000
# 1                en      27.920           8.3       22186      $160,000,000
# 2                en      15.041           6.1        3843      $165,000,000
# 3                en      20.340           6.0        4909       $68,000,000
# 4                en      28.515           6.8       12368      $170,000,000
#
#   domestic_gross_y worldwide_gross
# 0     $415,004,880  $1,068,879,522
# 1     $292,576,195    $835,524,642
# ...

# %% [markdown]
# We again check to see if there are any missing values in the specific columns in the DataFrame. We will also need to deal with them in order to come up with a strategy. We have three options for dealing with missing values removing them from the dataset, keeping them, or replacing them with another value.

# %%
# Checking for any missing values
merged_df.isna().any()
# Out:
# title                False
# studio                True
# genre_ids            False
# original_language    False
# popularity           False
# vote_average         False
# vote_count           False
# production_budget    False
# domestic_gross_y     False
# worldwide_gross      False
# dtype: bool

# %%
# Checking the number of missing values in the respective columns
merged_df.isna().sum() # Found 1 in the "studio" column
# Out:
# title                0
# studio               1
# genre_ids            0
# original_language    0
# popularity           0
# vote_average         0
# vote_count           0
# production_budget    0
# domestic_gross_y     0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# Since there is only one missing value in the studio column, we will remove the offending row.

# %%
# Dropping the offending row
merged_df = merged_df.dropna(subset = ["studio"])
merged_df.isna().sum()
merged_df.shape # This results in a shape of (1394, 10)
# Out:
# (1394, 10)

# %% [markdown]
# We check for duplicates, remove them then recheck again to ensure that duplicates no longer exist.

# %%
# Checking for duplicate values
merged_df.duplicated().value_counts()
# Out:
# False    1270
# True      124
# dtype: int64

# %%
# Dropping the duplicate values 
merged_df = merged_df.drop_duplicates()
merged_df.shape # This results in a shape of (1270, 10)
# Out:
# (1270, 10)

# %%
# Rechecking to ensure the duplicate values no longer exist
merged_df.duplicated().value_counts()
# Out:
# False    1270
# dtype: int64

# %% [markdown]
# Data preparation and analysis need the conversion of different data types, known as data casting. It entails converting a variable's data type from one format to another (for example, from string to integer or float). Data casting is significant because it can guarantee data accuracy, simplify analysis, and provide insightful information. In the next cwlls we will figure out the columns that require data casting by first checking the DataFrame's info.

# %%
df_info(merged_df)
# Out:
# df type:  <class 'pandas.core.frame.DataFrame'>
#
# df shape:  (1270, 10)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1270 entries, 0 to 1393
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1270 non-null   object
#  1   studio             1270 non-null   object
#  2   genre_ids          1270 non-null   object
#  3   original_language  1270 non-null   object
#  4   popularity         1270 non-null   float64
#  5   vote_average       1270 non-null   float64
#  6   vote_count         1270 non-null   int64
#  7   production_budget  1270 non-null   object
#  8   domestic_gross_y   1270 non-null   object
#  9   worldwide_gross    1270 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 109.1+ KB
# df info:  None
#
# df description:          popularity  vote_average    vote_count
# count  1270.000000   1270.000000   1270.000000
# ...

# %% [markdown]
# Fron the info, we need to convert three columns, namely: `production_budget`, `domestic_gross_y` and `worldwide_gross` from object type to float data types using the `astype()` function.We will also remove the dollar signs and commas in the `domestic_gross_y` and `worldwide_gross` columns by using `str.replace()`.

# %%
# Create a list of columns to clean and convert
clean_and_convert = ["production_budget", "domestic_gross_y", "worldwide_gross"]

# Remove dollar signs and commas, and convert to float for each column
for column in clean_and_convert:
    merged_df[column] = merged_df[column].str.replace("$", "").str.replace(",", "").astype(float)

merged_df.head()
# Out:
#                         title studio                genre_ids  \
# 0                 Toy Story 3     BV          [16, 10751, 35]
# 1                   Inception     WB            [28, 878, 12]
# 2         Shrek Forever After   P/DW  [35, 12, 14, 16, 10751]
# 3  The Twilight Saga: Eclipse   Sum.      [12, 14, 18, 10749]
# 4                  Iron Man 2   Par.            [12, 28, 878]
#
#   original_language  popularity  vote_average  vote_count  production_budget  \
# 0                en      24.445           7.7        8340        200000000.0
# 1                en      27.920           8.3       22186        160000000.0
# 2                en      15.041           6.1        3843        165000000.0
# 3                en      20.340           6.0        4909         68000000.0
# 4                en      28.515           6.8       12368        170000000.0
#
#    domestic_gross_y  worldwide_gross
# 0       415004880.0     1.068880e+09
# 1       292576195.0     8.355246e+08
# ...

# %%
df_info(merged_df) # Checking to see the data casted columns
# Out:
# df type:  <class 'pandas.core.frame.DataFrame'>
#
# df shape:  (1270, 10)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1270 entries, 0 to 1393
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1270 non-null   object
#  1   studio             1270 non-null   object
#  2   genre_ids          1270 non-null   object
#  3   original_language  1270 non-null   object
#  4   popularity         1270 non-null   float64
#  5   vote_average       1270 non-null   float64
#  6   vote_count         1270 non-null   int64
#  7   production_budget  1270 non-null   float64
#  8   domestic_gross_y   1270 non-null   float64
#  9   worldwide_gross    1270 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 109.1+ KB
# df info:  None
#
# df description:          popularity  vote_average    vote_count  production_budget  \
# ...

# %% [markdown]
# The dataset is now clean and ready for analysis. To improve the data, several crucial actions were conducted. At first, extraneous columns were removed, yielding a more concentrated dataset of shape (1395, 10). A single missing value in the'studio' column was quickly deleted when we meticulously used the `.isna()` method to check for missing values. As a consequence, we were left with a dataset that had the shape (1394, 10). The next crucial step was to use the `.duplicated()` method to find and handle duplicates. This revealed 124 duplicated values that were immediately removed, giving us a DataFrame with the shape (1270, 10). We data casted the `production_budget`, `domestic_gross_y`, and `worldwide_gross` columns to float data type to guarantee numerical consistency. Additionally, we used the `.str.replace()` method to remove dollar signs and commas from these columns and the `.astype()` method to convert the data types. These thorough data cleaning procedures have now prepared the dataset for intelligent analysis.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# A crucial turning point in our investigation of the film industry occurs during the data analysis stage, which enables us to extract significant patterns and insights from the compiled dataset. We used univariate, bivariate, and multivariate exploratory data analysis (EDA) methodologies in a comprehensive manner to properly analyze the data.
# Let's dive into our analysis.

# %% [markdown]
# ### Problem Statement 1: To profile the competitive landscape within the movie industry, including the performance of key players
# This inquiry aims to analyze the competitive dynamics of the film business. To comprehend their respective performances, it entails a detailed research of the studios. Microsoft can make strategic decisions about prospective alliances, collaborations, or areas of opportunity to build a solid footing in this competitive sector by acquiring knowledge into the competitive forces at play.

# %%
# Creating a copy of the merged dataset
studio_ratings_df = merged_df.copy()
studio_ratings_df.head()
# Out:
#                         title studio                genre_ids  \
# 0                 Toy Story 3     BV          [16, 10751, 35]
# 1                   Inception     WB            [28, 878, 12]
# 2         Shrek Forever After   P/DW  [35, 12, 14, 16, 10751]
# 3  The Twilight Saga: Eclipse   Sum.      [12, 14, 18, 10749]
# 4                  Iron Man 2   Par.            [12, 28, 878]
#
#   original_language  popularity  vote_average  vote_count  production_budget  \
# 0                en      24.445           7.7        8340        200000000.0
# 1                en      27.920           8.3       22186        160000000.0
# 2                en      15.041           6.1        3843        165000000.0
# 3                en      20.340           6.0        4909         68000000.0
# 4                en      28.515           6.8       12368        170000000.0
#
#    domestic_gross_y  worldwide_gross
# 0       415004880.0     1.068880e+09
# 1       292576195.0     8.355246e+08
# ...

# %%
studio_ratings_df["studio"].value_counts()
# Out:
# Uni.           136
# Fox            113
# WB             105
# BV              76
# Par.            76
#               ...
# Trib.            1
# WHE              1
# IM               1
# Jan.             1
# Global Road      1
# Name: studio, Length: 91, dtype: int64

# %% [markdown]
# Using bivariate analysis we plot a graph to check the dominance of the studios based on the number of movies they have released.

# %%
studio_movie_counts = studio_ratings_df['studio'].value_counts()

# Create a bar chart
figure, ax = plt.subplots(figsize =(8, 14))
sns.barplot(x=studio_movie_counts.values, y=studio_movie_counts.index, palette='viridis')
ax.set_xlabel('Number of movies')
ax.set_ylabel('Studio Name')
ax.set_title('Number of Movies Released by Studio')
plt.savefig("Number of Movies vs. Studio Name.png")

# %%
# Taking 'production_budget' and 'worldwide_gross' as the columns for budget and gross earnings
studio_success = studio_ratings_df.groupby('studio').agg({
    "production_budget" : "sum",   # Calculate total worldwide gross earnings
    "worldwide_gross": "sum" # Calculate total production budget spendings
})      

# Print success metrics
studio_success = studio_success.sort_values(by = "worldwide_gross", ascending = False).reset_index()
studio_success
# Out:
#    studio  production_budget  worldwide_gross
# 0      BV       1.027480e+10     3.775937e+10
# 1    Uni.       7.427700e+09     3.011561e+10
# 2     Fox       7.889500e+09     2.692971e+10
# 3      WB       8.510700e+09     2.329600e+10
# 4    Sony       5.052500e+09     1.760940e+10
# ..    ...                ...              ...
# 86     KE       3.600000e+07     1.899060e+05
# 87    Alc       1.000000e+07     1.610970e+05
# 88     DR       8.000000e+05     8.890400e+04
# 89  First       9.000000e+06     8.552700e+04
# 90    BBC       6.000000e+05     7.943000e+03
#
# [91 rows x 3 columns]

# %% [markdown]
# Next we examine the top studios based on worldwide gross and identify the dominant players in the industry. This helps in understanding which studios have consistently delivered successful movies.

# %%
# Dropping rows that have studios operating at a loss
gross_below = studio_success['production_budget'] > studio_success['worldwide_gross']
studio_success = studio_success.drop(studio_success[gross_below].index).reset_index(drop = True)
studio_success
# Out:
#        studio  production_budget  worldwide_gross
# 0          BV       1.027480e+10     3.775937e+10
# 1        Uni.       7.427700e+09     3.011561e+10
# 2         Fox       7.889500e+09     2.692971e+10
# 3          WB       8.510700e+09     2.329600e+10
# 4        Sony       5.052500e+09     1.760940e+10
# 5        Par.       4.885000e+09     1.480283e+10
# 6     WB (NL)       2.207600e+09     8.720197e+09
# 7         LGF       1.993388e+09     6.713787e+09
# 8        P/DW       1.334000e+09     5.078028e+09
# 9        LG/S       1.417200e+09     3.323112e+09
# 10      Wein.       8.055000e+08     2.619457e+09
# 11       SGem       7.275000e+08     2.399347e+09
# 12       FoxS       5.678600e+08     2.311533e+09
# 13      Focus       7.945000e+08     2.096645e+09
# 14      Rela.       8.235000e+08     1.569302e+09
# 15       TriS       4.668000e+08     1.530805e+09
# 16       Sum.       4.198000e+08     1.440522e+09
# 17        STX       5.691000e+08     1.240645e+09
# ...

# %% [markdown]
# Analyzing the distribution of worldwide gross among the top 20 studios can reveal how market share is distributed. You can identify if a few studios hold a significant portion of the market or if it's relatively evenly distributed.

# %%
# Create a bar plot to show the aove analysis
figure, ax = plt.subplots(figsize=(10, 10))
sns.barplot(x = studio_success['worldwide_gross'].head(20), y = studio_success['studio'].head(20))
ax.set_xlabel('Total Worldwide Gross Earnings')
ax.set_ylabel('Studio Name')
ax.set_title('Studio Success Metrics')
plt.savefig("Studio Name vs. Success Metrics.png")

# %% [markdown]
# The above analysis arises the following insights:
# * Competitive Benchmarking: A corporation can evaluate its position in the market by comparing its performance to that of its rivals through the strategic process known as competitive benchmarking. This analysis entails the identification of immediate competitors, the gathering and analysis of information, including financial metrics, and market share. Companies use this assessment to uncover best practices used by top competitors, identify strengths and weaknesses, create performance goals, execute changes, and continuously track progress. In the end, this iterative approach helps firms thrive in a competitive environment by fostering performance improvement, informed decision-making, market positioning and efficient strategy planning.To Microsoft, as a new company entering the industry, this analysis provides a benchmark to compare against. It helps in setting realistic goals for market share and revenue targets.

# %% [markdown]
# ### Problem Statement 2: To assess the success of different languages based on their worldwide gross earnings
# This analysis tries to reveal the importance of languages in the current box office scene. We want to determine which languages now control the global by comparing the global gross revenues of films released in a variety of languages. By taking into account audience preferences and enhancing global appeal, Microsoft will be able to make educated decisions about the preferred languages for its film productions.

# %%
# Creating a copy of the merged dataset.
languages_df = merged_df.copy()
languages_df.head()
# Out:
#                         title studio                genre_ids  \
# 0                 Toy Story 3     BV          [16, 10751, 35]
# 1                   Inception     WB            [28, 878, 12]
# 2         Shrek Forever After   P/DW  [35, 12, 14, 16, 10751]
# 3  The Twilight Saga: Eclipse   Sum.      [12, 14, 18, 10749]
# 4                  Iron Man 2   Par.            [12, 28, 878]
#
#   original_language  popularity  vote_average  vote_count  production_budget  \
# 0                en      24.445           7.7        8340        200000000.0
# 1                en      27.920           8.3       22186        160000000.0
# 2                en      15.041           6.1        3843        165000000.0
# 3                en      20.340           6.0        4909         68000000.0
# 4                en      28.515           6.8       12368        170000000.0
#
#    domestic_gross_y  worldwide_gross
# 0       415004880.0     1.068880e+09
# 1       292576195.0     8.355246e+08
# ...

# %%
languages_df["original_language"].value_counts()
# Out:
# en    1221
# fr      10
# hi       7
# ru       4
# es       4
# ko       3
# th       2
# it       2
# zh       2
# ar       2
# he       1
# sv       1
# pl       1
# tr       1
# da       1
# de       1
# xx       1
# el       1
# te       1
# fa       1
# no       1
# hu       1
# pt       1
# Name: original_language, dtype: int64

# %% [markdown]
# Using the `.map()`method on a pandas Series with a dictionary of values to replace the values in the `original_language` column to desired values that can be easily understood.

# %%
# Creating a dictionary with the abbreviations as keys and their respective full names as values.

language_mapping = {
   "ar" : "Arabic",
    "da" : "Danish",
    "de" : "German",
    "el" : "Greek",
    "en" : "English",
    "es" : "Spanish",
    "fa" : "Persian",
    "fr" : "French",
    "he" : "Hebrew",
    "hi" : "Hindi",
    "hu" : "Hungarian",
    "ko" : "Korean",
    "pl" : "Polish",
    "ru" : "Russian",
    "te" : "Telugu",
    "th" : "Thai",
    "tr" : "Turkish",
    "xx" : "Unknown"
}

# %%
# Call the .map() method to return a Series with the abbreviations transformed into full names:
languages_df["original_language"].map(language_mapping)
# Out:
# 0       English
# 1       English
# 2       English
# 3       English
# 4       English
#          ...
# 1389    English
# 1390    English
# 1391    English
# 1392    English
# 1393    English
# Name: original_language, Length: 1270, dtype: object

# %%
# Replace the "original_language" column in languages_df with these new, transformed values:
languages_df["original_language"] = languages_df["original_language"].map(language_mapping)
languages_df["original_language"].value_counts()
# Out:
# English      1221
# French         10
# Hindi           7
# Spanish         4
# Russian         4
# Korean          3
# Arabic          2
# Thai            2
# Persian         1
# Unknown         1
# Turkish         1
# Telugu          1
# Polish          1
# Danish          1
# German          1
# Hebrew          1
# Hungarian       1
# Greek           1
# Name: original_language, dtype: int64

# %% [markdown]
# We plot a bar graph to check the top 5 most common languages used based on the number of movies made in that language.

# %%
language_counts = languages_df["original_language"].value_counts()

# Plot a bar graph of the five most common languages
top_languages = language_counts.head()
figure, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x = top_languages.index, y = top_languages.values, ax=ax)
ax.set_xlabel("Languages")
ax.set_ylabel("Number of Movies")
ax.set_title("Top 5 Most Common Languages by Number of Movies")
plt.savefig("Number of Movies vs. Languages.png")

# %% [markdown]
# The top 5 most common languages are, English as the lead, French, Hindi, Spanish and Russian.

# %% [markdown]
# Next we evaluate the `worldwide_gross` associated by each of the top 5 most common languages and analayze which one produces high gross values.

# %%
# Calculate the top 5 most common languages based on count
x = languages_df["original_language"].value_counts().head().index
y = languages_df.groupby('original_language')['worldwide_gross'].mean().loc[x]

# Create a DataFrame for plotting
data_for_plot = pd.DataFrame({'Languages': x, 'Worldwide Gross Revenue': y})

# Plot a bar graph of the five most common languages
figure, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=data_for_plot, x='Languages', y='Worldwide Gross Revenue', ax=ax)
ax.set_xlabel("Top 5 Languages")
ax.set_ylabel("Worldwide Gross Revenue")
ax.set_title("Top Multilingual Languages by Average Worldwide Gross Revenue")
plt.savefig("Top Multilingual Languages vs. Average Worldwide Gross Revenue.png")

# %% [markdown]
# When compared to films in other languages, the study of the movie dataset shows that English-language films regularly have the greatest worldwide box office take. Several things can be used to support this conclusion. First off, as English is one of the most extensively used languages in the world, a larger audience for English-language films is possible. In addition, many English-language films are produced by renowned studios, which can increase their marketability and appeal to a broad audience.
# Therefore, Microsoft should consider producing a significant portion of its movie portfolio in English. This aligns with the global appeal of English-language cinema and its potential to reach a broader audience.

# %% [markdown]
# ### Problem Statement 3: To assess the financial implications of production budgets on the performance of movies
# This analysis explores the financial aspects of the film industry, focusing on the connection between production costs and total film quality. by looking at how spending on a film's budget affects its commercial success. These data will enable Microsoft's film division to allocate resources intelligently, assuring the best possible financial results while creating high-caliber cinematic experiences.

# %%
# Creating aa copy of the merged dataset
budgets_df = merged_df.copy()
budgets_df.head()
# Out:
#                         title studio                genre_ids  \
# 0                 Toy Story 3     BV          [16, 10751, 35]
# 1                   Inception     WB            [28, 878, 12]
# 2         Shrek Forever After   P/DW  [35, 12, 14, 16, 10751]
# 3  The Twilight Saga: Eclipse   Sum.      [12, 14, 18, 10749]
# 4                  Iron Man 2   Par.            [12, 28, 878]
#
#   original_language  popularity  vote_average  vote_count  production_budget  \
# 0                en      24.445           7.7        8340        200000000.0
# 1                en      27.920           8.3       22186        160000000.0
# 2                en      15.041           6.1        3843        165000000.0
# 3                en      20.340           6.0        4909         68000000.0
# 4                en      28.515           6.8       12368        170000000.0
#
#    domestic_gross_y  worldwide_gross
# 0       415004880.0     1.068880e+09
# 1       292576195.0     8.355246e+08
# ...

# %% [markdown]
# The aim is to plot scatter plots which are crucial for data-driven decision-making in the movie industry. They provide insights into how financial investments in production budgets correlate with revenue generation and how domestic and global markets interact. This information informs budgeting, marketing, and distribution strategies, ultimately contributing to the financial success of movie projects.
#
# * Worldwide Gross vs. Production Budget: To establish whether there is a positive correlation, a scatter plot of the worldwide gross (on the y-axis) against the production budget (on the x-axis) is used. A positive association exists between production budget and worldwide gross if the majority of the data points cluster from left to right in an upward direction. Making decisions on how to allocate funds for film production requires this understanding.
#
#
# * Domestic Gross vs. Worldwide Gross: A scatter plot of domestic gross (on the x-axis) and worldwide gross (on the y-axis) shows how domestic and international revenues are related. If there is a significant positive correlation, it may mean that films that do well domestically also frequently do well internationally, which could have an impact on distribution and marketing plans.
#
#
# * Domestic Gross vs. Production Budget: To determine the effect of the production budget on domestic earnings, a scatter plot of the production budget (on the x-axis) against domestic gross (on the y-axis) is used. A positive association would suggest that larger spending and bigger domestic gross are related, informing marketing and target audience decisions.

# %%
# Create subplots for domestic gross and worldwide gross

# Domestic Gross vs. Production Budget
fig, ax1= plt.subplots(figsize=(10, 6))

sns.scatterplot(data = budgets_df, x = "production_budget", y = "domestic_gross_y")
ax1.set_xlabel("Production Budget")
ax1.set_ylabel("Domestic Gross")
ax1.set_title("Production Budget vs. Domestic Gross")
plt.savefig("Production Budget vs. Domestic Gross.png")

# Worlwide Gross vs. Production Budget
fig, ax2 = plt.subplots(figsize=(10, 6))

sns.scatterplot(data = budgets_df, x = "production_budget", y = "worldwide_gross")
ax2.set_xlabel("Production Budget")
ax2.set_ylabel("Worldwide Gross")
ax2.set_title("Production Budget vs. Worldwide Gross")
plt.savefig("Production Budget vs. Worldwide Gross.png")

# Domestic Gross vs. Worldwide Gross
fig, ax3 = plt.subplots(figsize = (10, 6))
sns.scatterplot(data = budgets_df, x = "domestic_gross_y", y = "worldwide_gross")
ax3.set_xlabel("Domestic Gross")
ax3.set_ylabel("Worldwide Gross")
ax3.set_title("Domestic Gross vs. Worldwide Gross")
plt.savefig("Domestic Gross vs. Worldwide Gross.png")

# %%
# Creating a function that returns the correlation coefficients between the specified columns
def correlation (x, y):
    corr = np.corrcoef(x, y)
    return corr[0][1]

# %%
# Calculate the correlation coefficients
# To quantitatively measure the strength and direction of the relationship between production budgets and gross earnings. 
# A positive correlation suggests that higher budgets lead to higher earnings.
x = budgets_df["production_budget"]
y = budgets_df["domestic_gross_y"]

x1 = budgets_df["production_budget"]
y1 = budgets_df["worldwide_gross"]

x3 = budgets_df["domestic_gross_y"]
y3 = budgets_df["worldwide_gross"]

print("The correlation between Production budget and Domestic gross is: ", correlation(x, y))
print("The correlation between Production budget and Worldwide gross is: ", correlation(x1, y1))
print("The correlation between Production budget and Worldwide gross is: ", correlation(x3, y3))
# Out:
# The correlation between Production budget and Domestic gross is:  0.6985841005507146
# The correlation between Production budget and Worldwide gross is:  0.7791527956492643
# The correlation between Production budget and Worldwide gross is:  0.9404679571013228

# %% [markdown]
# * Domestic Gross and Production Budget: There exists a moderately strong positive relationship between the `production_budget` invested in a movie and its `domestic_gross_y` earnings. This finding suggests that allocating higher budgets to movie production is associated with a greater likelihood of achieving higher earnings in the domestic market.
#
# * Worldwide Gross and Production Budget: Similarly, the positive correlation between `worldwide_gross` and `production_budget` indicates that higher production budgets are linked to increased worldwide gross earnings. This emphasizes the financial impact of strategic budget allocation in movie production.
#
# * Domestic Gross and Worldwide Gross: The notably high correlation between `domestic_gross_y` and `worldwide_gross` highlights that movies performing well domestically tend to perform exceptionally well on the global stage. This underlines the interconnected nature of these markets and the potential to leverage domestic success for international appeal.
#
# These strong positive connections highlight the financial significance of production budget allocation in the film business, to sum up. In light of the fact that wise production investments can have a major impact on both domestic and international profitability, Microsoft's new film studio should take these findings into account when deciding how much money to allocate to filmmaking. Recognizing the interdependence of the domestic and international markets further highlights the importance of flexible distribution and marketing tactics for maximizing profit potential.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The research of the movie dataset has revealed some significant trends that can direct Microsoft's new movie studio in its foray into the film industry:
#
# * Language Choice: English-language movies tend to achieve the highest worldwide gross, highlighting the global appeal of English cinema. Microsoft should consider producing a significant portion of its movie portfolio in English to tap into this broad audience.
#
# * Budget Allocation: The production budget and both domestic and global gross have a strong positive link. This suggests that strategic budget allocation can have a big impact on generating revenue. To maximize revenue, Microsoft should carefully manage and spend its budgets.he remarkably strong correlation between domestic and international box office revenue shows that films that do well domestically also frequently do well internationally. Microsoft may use its local success to broaden its appeal internationally.
#
# * Collaboration and Competition: It is crucial to comprehend the competitive environment. Microsoft ought to be aware of the market share and effective strategies of other significant studios. To increase its influence and reach, chances for partnership with other studios or distribution channels can also be investigated.

# %% [markdown]
# It's important to recognize that this study has significant limitations, though. Because the film industry is subject to changing trends and audience preferences, the dataset used only represents historical data. In addition, elements including marketing tactics, timing of the release, and critical acclaim play important roles in a movie's success and weren't completely examined in this analysis.

# %% [markdown]
# ### Next Steps
# Microsoft's film division might take the following into account to enhance this project in the future:
#
# * Conducting market research: To identify current consumer preferences and trends can help writers decide on scripts and genres.
#
# * Comprehensive Data: Adding more recent data and a larger range of factors to the dataset, such as marketing spending, genre-specific insights, and important reception measures.
#
# * Competitive investigation: Carrying out a thorough investigation of the competition to compare studios with success and find best practices.
#
# By using predictive modeling and machine learning, movie performance may be predicted based on a variety of variables, allowing for data-driven decision-making.
